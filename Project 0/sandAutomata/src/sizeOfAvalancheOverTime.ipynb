# %%
import numpy as np


sizeOfAvalancheOverTime = np.loadtxt("../sizeOfAvalancheOverTime.txt")
sizeOfAvalancheOverTime
# Out:
# array([0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        2.000e+00, 4.000e+00, 1.000e+01, 8.000e+00, 1.700e+01, 1.000e+01,
#        1.700e+01, 3.200e+01, 6.500e+01, 7.400e+01, 1.560e+02, 1.710e+02,
#        3.270e+02, 1.070e+03, 2.021e+03, 2.687e+03, 2.311e+03, 2.525e+03,
#        2.743e+03, 2.748e+03, 2.235e+03, 2.123e+03, 3.031e+03, 2.106e+03,
#        2.541e+03, 3.096e+03, 2.153e+03, 2.447e+03, 2.685e+03, 2.512e+03,
#        2.267e+03, 2.341e+03, 2.945e+03, 2.293e+03, 1.914e+03, 3.445e+03,
#        2.065e+03, 2.901e+03, 2.363e+03, 3.009e+03, 2.108e+03, 3.350e+03,
#        3.261e+03, 2.356e+03, 2.260e+03, 2.541e+03, 2.685e+03, 2.481e+03,
#        2.340e+03, 2.883e+03, 2.433e+03, 2.226e+03, 2.159e+03, 2.808e+03,
#        2.777e+03, 2.433e+03, 2.172e+03, 2.539e+03, 2.493e+03, 2.954e+03,
#        2.619e+03, 2.291e+03, 2.784e+03, 3.029e+03, 2.524e+03, 2.358e+03,
#        1.846e+03, 3.414e+03, 1.941e+03, 2.784e+03, 2.876e+03, 1.715e+03,
# ...

# %%
import matplotlib.pyplot as plt


plt.xlabel("Steps")
plt.ylabel("Size of Avalanches")

plt.title("Sand Automata: Size of Avalanche over Time")

plt.plot(sizeOfAvalancheOverTime)
